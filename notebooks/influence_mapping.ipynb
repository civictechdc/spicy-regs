# %% [markdown]
# # Influence Mapping
#
# **Problem**: How can we link public comments to specific changes in final rules and identify which commenters influenced regulatory outcomes?
#
# **Stakeholder Quotes:**
# - "Develop tools to assess whether and how comments influenced the final rule."
# - "Which entities actually impact regulatory filings?"
#
# This notebook demonstrates:
# - Identifying high-impact commenters
# - Tracking comment-to-rule connections
# - Analyzing agency responsiveness patterns

# %%
import duckdb
import pandas as pd

R2_BASE_URL = "https://pub-5fc11ad134984edf8d9af452dd1849d6.r2.dev"

conn = duckdb.connect()
conn.execute("INSTALL httpfs; LOAD httpfs;")
print("✓ Ready")
# Out:
# ✓ Ready

# %% [markdown]
# ## 1. Identify High-Impact Commenters
#
# Find organizations that frequently submit detailed comments.

# %%
# Commenters with long, substantive comments across multiple dockets
high_impact = conn.execute(f"""
    SELECT 
        title as commenter,
        COUNT(*) as total_comments,
        COUNT(DISTINCT docket_id) as dockets,
        COUNT(DISTINCT agency_code) as agencies,
        AVG(LENGTH(comment)) as avg_length
    FROM read_parquet('{R2_BASE_URL}/comments.parquet')
    WHERE title IS NOT NULL
      AND LENGTH(comment) > 1000  -- Substantive comments only
    GROUP BY title
    HAVING COUNT(DISTINCT docket_id) > 10
    ORDER BY dockets DESC, avg_length DESC
    LIMIT 30
""").fetchdf()

print("High-impact commenters (substantive comments across many dockets):")
high_impact
# Out:
# High-impact commenters (substantive comments across many dockets):
#                                           commenter  total_comments  dockets  \
# 0                            Comment from Anonymous          136803     2799
# 1                          Anonymous public comment           37889     1685
# 2   Submitted Electronically via eRulemaking Portal          343477      575
# 3                    Comment Submitted by Anonymous           20673      438
# 4                  Comment from Anonymous Anonymous            8103      417
# 5                                         Anonymous            3916      365
# 6                           Comment on FR Doc # N/A           78883      334
# 7                              Anonymous - Comments            2055      271
# 8                           Comment from WhoPoo App             232      210
# 9                          Anonymous Public Comment            5971      168
# 10                   Comment from Lish, Christopher             182      128
# 11                              Anonymous - Comment             394      121
# 12                    Comment from Christopher Lish             127      119
# 13                                               CA           18885      108
# 14                   Comment submitted by B. Sachau             110      103
# 15                 Comment from anonymous anonymous             424      103
# 16                      Comment from Albanese, Dawn             195      103
# 17                          Comment from Angell, JL             261       99
# 18                 Comment from Valentine, Jennifer             275       96
# 19                      Comment from Stewart, Sarah             227       96
# 20                       Comment from Lytle, Denise             231       95
# 21                   Comment from Mennel-Bell, Mari             199       94
# 22                      Comment from Shallman, Elsy             177       93
# 23                     Comment submitted by C. Lish             100       92
# 24                      Comment from Bradley, Kathy             176       92
# 25                      Comment from Stern, Richard             270       92
# 26                    Comment from Chinofsky, Laura             236       92
# 27                        Comment from Bostock, Vic             201       91
# 28                   Comment from Link-New, Virgene             189       91
# 29                                               DC             960       90
#
#     agencies   avg_length
# 0         59  2007.894513
# 1          7  1989.673573
# 2          2  1765.645807
# 3         13  2038.952789
# 4         35  2351.049981
# 5         21  2195.596272
# 6         58  1930.027940
# 7         12  1862.339659
# 8         29  3090.086207
# 9          3  1864.821973
# 10        17  2697.532967
# 11         4  1778.230964
# 12        22  3214.803150
# 13         3  1738.311305
# 14         4  4884.281818
# 15        18  2123.856132
# 16        15  2101.364103
# 17        19  2115.440613
# 18        13  2177.392727
# 19        12  2035.022026
# 20        15  2028.424242
# 21        15  2290.562814
# 22        16  2092.316384
# 23         1  3624.380000
# 24        17  2219.346591
# 25        16  2104.348148
# 26        12  2102.733051
# 27        12  2106.184080
# 28        13  2052.005291
# 29         2  2366.406250

# %% [markdown]
# ## 2. Agency Responsiveness Analysis
#
# Which agencies receive the most public engagement?

# %%
# Comment volume by agency
agency_engagement = conn.execute(f"""
    SELECT 
        agency_code,
        COUNT(*) as total_comments,
        COUNT(DISTINCT docket_id) as dockets,
        ROUND(COUNT(*) * 1.0 / COUNT(DISTINCT docket_id), 1) as avg_comments_per_docket
    FROM read_parquet('{R2_BASE_URL}/comments.parquet')
    GROUP BY agency_code
    ORDER BY total_comments DESC
    LIMIT 20
""").fetchdf()

print("Agencies by public comment volume:")
agency_engagement
# Out:
# Agencies by public comment volume:
#    agency_code  total_comments  dockets  avg_comments_per_docket
# 0          FWS         2489321     1624                   1532.8
# 1          FDA         1807294     5097                    354.6
# 2          CMS         1289068     1269                   1015.8
# 3          EPA         1122190     9349                    120.0
# 4          HHS         1089930      157                   6942.2
# 5         CFPB         1062348      437                   2431.0
# 6          CEQ         1025541       16                  64096.3
# 7           ED          980398     1410                    695.3
# 8          ATF          975423       22                  44337.4
# 9          BLM          848986       57                  14894.5
# 10         DOI          815581       55                  14828.7
# 11        NOAA          728325     1800                    404.6
# 12         WHD          610771       32                  19086.6
# 13        BOEM          589486      262                   2249.9
# 14          FS          586112      108                   5427.0
# 15       APHIS          544134     1148                    474.0
# 16         FNS          423656      303                   1398.2
# 17        OSHA          386362      857                    450.8
# 18          VA          365658      341                   1072.3
# 19         FAA          357003    11485                     31.1

# %% [markdown]
# ## 3. Track Entity Across Rulemaking

# %%
# Track a specific org's regulatory engagement
org_name = "Chamber of Commerce"  # Change this

org_history = conn.execute(f"""
    SELECT 
        c.agency_code,
        c.docket_id,
        d.title as docket_title,
        c.posted_date,
        LENGTH(c.comment) as comment_length
    FROM read_parquet('{R2_BASE_URL}/comments.parquet') c
    LEFT JOIN read_parquet('{R2_BASE_URL}/dockets.parquet') d
        ON c.docket_id = d.docket_id
    WHERE LOWER(c.title) LIKE '%{org_name.lower()}%'
    ORDER BY c.posted_date DESC
    LIMIT 20
""").fetchdf()

print(f"{org_name} regulatory engagement:")
org_history
# Out:
# Chamber of Commerce regulatory engagement:
#    agency_code              docket_id  \
# 0          EPA    EPA-HQ-OW-2025-0322
# 1          EPA    EPA-HQ-OW-2025-0322
# 2          EPA  EPA-HQ-OPPT-2020-0549
# 3          EPA  EPA-HQ-OPPT-2020-0549
# 4          EPA  EPA-HQ-OPPT-2020-0549
# 5          FWS    FWS-HQ-ES-2025-0039
# 6          FWS    FWS-HQ-ES-2025-0044
# 7          FWS    FWS-HQ-ES-2025-0044
# 8          FWS    FWS-HQ-ES-2025-0048
# 9          FWS    FWS-HQ-ES-2025-0048
# 10         FWS    FWS-HQ-ES-2025-0039
# 11         FWS    FWS-HQ-ES-2025-0029
# 12         FWS    FWS-HQ-ES-2025-0029
# 13         EPA  EPA-R09-OAR-2025-2833
# 14         FDA        FDA-2025-N-0835
# 15        CFPB         CFPB-2025-0039
# 16        BOEM         BOEM-2025-0483
# 17         BIS          BIS-2025-0023
# 18         EPA   EPA-HQ-OAR-2025-1477
# 19       USCIS        USCIS-2025-0271
#
#                                          docket_title           posted_date  \
# 0   Updated Definition of Waters of the United States  2026-01-08T05:00:00Z
# 1   Updated Definition of Waters of the United States  2026-01-08T05:00:00Z
# 2   Reporting and Recordkeeping for Perfluoroalkyl...  2025-12-31T05:00:00Z
# 3   Reporting and Recordkeeping for Perfluoroalkyl...  2025-12-31T05:00:00Z
# 4   Reporting and Recordkeeping for Perfluoroalkyl...  2025-12-31T05:00:00Z
# 5   Endangered and Threatened Wildlife and Plants;...  2025-12-23T05:00:00Z
# 6   Endangered and Threatened Wildlife and Plants;...  2025-12-23T05:00:00Z
# 7   Endangered and Threatened Wildlife and Plants;...  2025-12-23T05:00:00Z
# 8   Endangered and Threatened Wildlife and Plants;...  2025-12-23T05:00:00Z
# 9   Endangered and Threatened Wildlife and Plants;...  2025-12-23T05:00:00Z
# 10  Endangered and Threatened Wildlife and Plants;...  2025-12-23T05:00:00Z
# 11  Endangered and Threatened Wildlife and Plants;...  2025-12-23T05:00:00Z
# 12  Endangered and Threatened Wildlife and Plants;...  2025-12-23T05:00:00Z
# 13  Determination of Attainment by the Attainment ...  2025-12-19T05:00:00Z
# 14  Modified Risk Tobacco Product Application: App...  2025-12-18T05:00:00Z
# 15       Equal Credit Opportunity Act (Regulation B).  2025-12-16T05:00:00Z
# 16  Notice of Availability of the 11th National Ou...  2025-12-14T05:00:00Z
# 17  Adoption and Procedures of the Section 232 Ste...  2025-12-12T05:00:00Z
# 18  Visibility Protection: Regional Haze State Pla...  2025-12-02T05:00:00Z
# 19  Removal of the Automatic Extension of Employme...  2025-12-01T05:00:00Z
#
#     comment_length
# 0               20
# 1               93
# 2               20
# 3               20
# 4               20
# 5               59
# 6               90
# 7               47
# 8               59
# 9               84
# 10              90
# 11              86
# 12              20
# 13             127
# 14            3656
# 15              12
# 16              20
# 17              20
# 18             127
# 19              61

# %% [markdown]
# ## 4. Comment Length as Influence Proxy
#
# Longer, more detailed comments may indicate greater effort and potential influence.

# %%
# Find the most detailed comments in a docket
docket_id = "EPA-HQ-OAR-2021-0317"  # Change this

detailed_comments = conn.execute(f"""
    SELECT 
        comment_id,
        title as commenter,
        LENGTH(comment) as length,
        posted_date
    FROM read_parquet('{R2_BASE_URL}/comments.parquet')
    WHERE docket_id = '{docket_id}'
      AND comment IS NOT NULL
    ORDER BY LENGTH(comment) DESC
    LIMIT 20
""").fetchdf()

print(f"Most detailed comments on {docket_id}:")
detailed_comments
# Out:
# Most detailed comments on EPA-HQ-OAR-2021-0317:
#                    comment_id  \
# 0   EPA-HQ-OAR-2021-0317-2490
# 1   EPA-HQ-OAR-2021-0317-2195
# 2   EPA-HQ-OAR-2021-0317-0784
# 3   EPA-HQ-OAR-2021-0317-2241
# 4   EPA-HQ-OAR-2021-0317-0196
# 5   EPA-HQ-OAR-2021-0317-2154
# 6   EPA-HQ-OAR-2021-0317-0745
# 7   EPA-HQ-OAR-2021-0317-1613
# 8   EPA-HQ-OAR-2021-0317-1349
# 9   EPA-HQ-OAR-2021-0317-0672
# 10  EPA-HQ-OAR-2021-0317-0899
# 11  EPA-HQ-OAR-2021-0317-2293
# 12  EPA-HQ-OAR-2021-0317-0340
# 13  EPA-HQ-OAR-2021-0317-1368
# 14  EPA-HQ-OAR-2021-0317-2300
# 15  EPA-HQ-OAR-2021-0317-1146
# 16  EPA-HQ-OAR-2021-0317-0683
# 17  EPA-HQ-OAR-2021-0317-0557
# 18  EPA-HQ-OAR-2021-0317-1199
# 19  EPA-HQ-OAR-2021-0317-0327
#
#                                             commenter  length  \
# 0   Mass Comment Campaign sponsored by Mom Clean A...    7789
# 1   Comment submitted by Environmental Health Proj...    5274
# 2                    Comment submitted by Shawn Dolan    5240
# 3   Comment submitted by Public Lands Policy Coord...    5240
# 4   Comment submitted by Evangelical Environmental...    5236
# 5                 Comment submitted by Jessie Henshaw    5229
# 6         Comment submitted by Step 2 Compliance, LLC    5207
# 7                Comment submitted by Barbara Brandom    5182
# 8               Comment submitted by Theodora Tsongas    5105
# 9                 Comment submitted by Lauri Costello    5096
# 10              Comment submitted by Katherine C Jain    5091
# 11                Comment submitted by Stanley Holmes    5063
# 12  Comment submitted by Mothers & Others For Clea...    5036
# 13                  Comment submitted by Karen Artell    5020
# 14  Comment submitted by Science and Environmental...    5019
# 15               Comment submitted by Peter Schofield    4920
# 16                  Comment submitted by David Wojick    4793
# 17  Comment submitted by Union for Reform Judaism ...    4787
# 18                    Comment submitted by Gary Hogan    4664
# 19                   Comment submitted by Lisa Deaton    4633
#
#              posted_date
# 0   2023-02-24T05:00:00Z
# 1   2023-02-14T05:00:00Z
# 2   2022-02-02T05:00:00Z
# 3   2023-02-14T05:00:00Z
# 4   2021-12-01T05:00:00Z
# 5   2023-02-06T05:00:00Z
# 6   2022-02-02T05:00:00Z
# 7   2023-01-09T05:00:00Z
# 8   2022-02-07T05:00:00Z
# 9   2022-02-02T05:00:00Z
# 10  2022-02-03T05:00:00Z
# 11  2023-02-15T05:00:00Z
# 12  2021-12-10T05:00:00Z
# 13  2022-02-07T05:00:00Z
# 14  2023-02-15T05:00:00Z
# 15  2022-02-04T05:00:00Z
# 16  2022-02-02T05:00:00Z
# 17  2022-02-01T05:00:00Z
# 18  2022-02-04T05:00:00Z
# 19  2021-12-10T05:00:00Z

# %% [markdown]
# ## 5. Early vs Late Commenters
#
# Early commenters may have more influence on shaping the discourse.

# %%
# Who commented first vs last?
timing = conn.execute(f"""
    WITH ranked AS (
        SELECT 
            comment_id,
            title,
            posted_date,
            ROW_NUMBER() OVER (ORDER BY posted_date ASC) as rank_early,
            ROW_NUMBER() OVER (ORDER BY posted_date DESC) as rank_late
        FROM read_parquet('{R2_BASE_URL}/comments.parquet')
        WHERE docket_id = '{docket_id}'
          AND posted_date IS NOT NULL
          AND LENGTH(comment) > 500
    )
    SELECT * FROM ranked
    WHERE rank_early <= 10 OR rank_late <= 10
    ORDER BY posted_date
""").fetchdf()

print("Early and late substantive commenters:")
timing
# Out:
# Early and late substantive commenters:
#                    comment_id  \
# 0   EPA-HQ-OAR-2021-0317-0187
# 1   EPA-HQ-OAR-2021-0317-0188
# 2   EPA-HQ-OAR-2021-0317-0194
# 3   EPA-HQ-OAR-2021-0317-0196
# 4   EPA-HQ-OAR-2021-0317-0209
# 5   EPA-HQ-OAR-2021-0317-0212
# 6   EPA-HQ-OAR-2021-0317-0208
# 7   EPA-HQ-OAR-2021-0317-0202
# 8   EPA-HQ-OAR-2021-0317-0203
# 9   EPA-HQ-OAR-2021-0317-0311
# 10  EPA-HQ-OAR-2021-0317-2858
# 11  EPA-HQ-OAR-2021-0317-2882
# 12  EPA-HQ-OAR-2021-0317-2888
# 13  EPA-HQ-OAR-2021-0317-2887
# 14  EPA-HQ-OAR-2021-0317-2884
# 15  EPA-HQ-OAR-2021-0317-2886
# 16  EPA-HQ-OAR-2021-0317-2889
# 17  EPA-HQ-OAR-2021-0317-2890
# 18  EPA-HQ-OAR-2021-0317-4061
# 19  EPA-HQ-OAR-2021-0317-4066
#
#                                                 title           posted_date  \
# 0                 Comment submitted by Bridget Bailey  2021-11-23T05:00:00Z
# 1                  Comment submitted by Erica Mulcahy  2021-11-23T05:00:00Z
# 2                   Comment submitted by Dennis Groce  2021-12-01T05:00:00Z
# 3   Comment submitted by Evangelical Environmental...  2021-12-01T05:00:00Z
# 4                Comment submitted by Daurie Pollitto  2021-12-02T05:00:00Z
# 5                            Anonymous public comment  2021-12-02T05:00:00Z
# 6                            Anonymous public comment  2021-12-02T05:00:00Z
# 7                    Comment submitted by Amy Sindorf  2021-12-02T05:00:00Z
# 8                            Anonymous public comment  2021-12-02T05:00:00Z
# 9                   Comment submitted by Robert Perry  2021-12-10T05:00:00Z
# 10  Mass Comment Campaign sponsored by members of ...  2023-03-30T04:00:00Z
# 11  Mass Comment Campaign sponsoring organization ...  2023-03-30T04:00:00Z
# 12                  Comment submitted by A.L. Steiner  2023-04-07T04:00:00Z
# 13                  Comment submitted by Jared Meyers  2023-04-07T04:00:00Z
# 14                 Comment submitted by Joerg Sattler  2023-04-07T04:00:00Z
# 15               Comment submitted by Susan Wetherall  2023-04-07T04:00:00Z
# 16              Comment submitted by Melanie Zarnoski  2023-04-07T04:00:00Z
# 17                     Comment submitted by Liz Leske  2023-04-07T04:00:00Z
# 18                  Comment submitted by Clean Future  2024-08-28T04:00:00Z
# 19  Comment submitted by Air Quality Division (AQD...  2024-09-09T04:00:00Z
#
#     rank_early  rank_late
# 0            2        626
# 1            1        627
# 2            3        624
# 3            4        625
# 4            9        619
# 5            8        620
# 6            7        621
# 7            6        622
# 8            5        623
# 9           10        599
# 10         614          9
# 11         619         10
# 12         620          3
# 13         621          4
# 14         622          5
# 15         623          6
# 16         624          7
# 17         625          8
# 18         626          2
# 19         627          1

# %% [markdown]
# ## 6. Future: Proposed→Final Rule Diffing
#
# To truly measure influence, we'd need to:
# 1. Extract text from proposed rules
# 2. Extract text from final rules
# 3. Identify changes between versions
# 4. Match changes to comment arguments
#
# This requires access to the full document text (beyond current metadata).

# %%
# Placeholder for future implementation
print("""
Influence Scoring Framework (Future Work):

1. Document Retrieval
   - Fetch proposed rule PDF/HTML
   - Fetch final rule PDF/HTML
   
2. Change Detection
   - Diff documents section by section
   - Identify substantive changes vs formatting
   
3. Comment Matching
   - Extract key arguments from comments
   - Match arguments to rule changes
   - Score similarity using embeddings
   
4. Influence Attribution
   - Rank commenters by matched changes
   - Weight by change significance
   - Generate influence reports
""")
# Out:
# Influence Scoring Framework (Future Work):
#
# 1. Document Retrieval
#    - Fetch proposed rule PDF/HTML
#    - Fetch final rule PDF/HTML
#
# 2. Change Detection
#    - Diff documents section by section
#    - Identify substantive changes vs formatting
#
# 3. Comment Matching
#    - Extract key arguments from comments
#    - Match arguments to rule changes
#    - Score similarity using embeddings
#
# 4. Influence Attribution
#    - Rank commenters by matched changes
#    - Weight by change significance
#    - Generate influence reports
