# %% [markdown]
# # Spicy Regs Data Access
#
# Query federal regulations data from Cloudflare R2 using DuckDB.
#
# Data source: [regulations.gov](https://www.regulations.gov/) via [Mirrulations](https://github.com/MoravianUniversity/mirrulations)

# %%
# Install dependencies (run once)
# !pip install duckdb pandas

# %%
import duckdb

# R2 public URL for Spicy Regs data
R2_BASE_URL = "https://pub-5fc11ad134984edf8d9af452dd1849d6.r2.dev"

# Initialize DuckDB with HTTP support
conn = duckdb.connect()
conn.execute("INSTALL httpfs; LOAD httpfs;")
print("✓ DuckDB initialized with HTTP support")
# Out:
# ✓ DuckDB initialized with HTTP support

# %% [markdown]
# ## Data Overview
#
# The data is stored in 3 Parquet files:
# - `dockets.parquet` - Regulatory dockets (rulemaking proceedings)
# - `documents.parquet` - Documents within dockets (proposed rules, notices)
# - `comments.parquet` - Public comments on documents

# %%
# Get data statistics
for data_type in ["dockets", "documents", "comments"]:
    url = f"{R2_BASE_URL}/{data_type}.parquet"
    result = conn.execute(f"""
        SELECT 
            COUNT(*) as total_rows,
            COUNT(DISTINCT agency_code) as agencies
        FROM read_parquet('{url}')
    """).fetchone()
    print(f"{data_type}: {result[0]:,} rows, {result[1]} agencies")
# Out:
# dockets: 346,173 rows, 194 agencies
# documents: 2,009,957 rows, 315 agencies
# comments: 24,774,674 rows, 178 agencies

# %% [markdown]
# ## Query Dockets

# %%
# Recent EPA dockets
conn.execute(f"""
    SELECT docket_id, title, docket_type, modify_date
    FROM read_parquet('{R2_BASE_URL}/dockets.parquet')
    WHERE agency_code = 'EPA'
    ORDER BY modify_date DESC
    LIMIT 10
""").fetchdf()
# Out:
#                docket_id                                              title  \
# 0    EPA-HQ-OW-2025-0322  Updated Definition of Waters of the United States
# 1   EPA-HQ-OPP-2024-0239  Pyriofenone on Apple and Cherry subgroup 12-12...
# 2  EPA-R08-OAR-2021-0418  CR Group, LLC - Tekoi Landfill, Part 71 Renewa...
# 3  EPA-HQ-OPPT-2020-0549  Reporting and Recordkeeping for Perfluoroalkyl...
# 4  EPA-R09-OAR-2025-1938  Air Plan Approval; California; San Joaquin Val...
# 5    EPA-HQ-OA-2006-0734                               EPA Training Dockets
# 6  EPA-HQ-OPPT-2018-0503  Dibutyl phthalate (DBP) (1,2-Benzene- dicarbox...
# 7  EPA-HQ-OPPT-2018-0501  Butyl benzyl phthalate (BBP) 1,2-Benzene- dica...
# 8  EPA-HQ-OPPT-2018-0433  Di-ethylhexyl phthalate (DEHP)(1,2-Benzene- di...
# 9  EPA-R08-OAR-2025-0669  Marathon Oil Company - Brodahl Pad, Synthetic ...
#
#      docket_type           modify_date
# 0     Rulemaking  2026-01-14T21:11:07Z
# 1     Rulemaking  2026-01-14T19:51:45Z
# 2  Nonrulemaking  2026-01-14T18:33:24Z
# 3     Rulemaking  2026-01-14T18:23:07Z
# 4     Rulemaking  2026-01-14T17:50:00Z
# 5     Rulemaking  2026-01-14T17:27:45Z
# 6  Nonrulemaking  2026-01-14T16:39:00Z
# 7  Nonrulemaking  2026-01-14T16:11:41Z
# 8  Nonrulemaking  2026-01-14T16:06:59Z
# 9  Nonrulemaking  2026-01-14T15:53:42Z

# %%
# Top agencies by docket count
conn.execute(f"""
    SELECT agency_code, COUNT(*) as docket_count
    FROM read_parquet('{R2_BASE_URL}/dockets.parquet')
    GROUP BY agency_code
    ORDER BY docket_count DESC
    LIMIT 15
""").fetchdf()
# Out:
#    agency_code  docket_count
# 0          FDA         74303
# 1          FAA         58578
# 2          EPA         34093
# 3          DOT         14520
# 4         USCG         14055
# 5        FMCSA         10093
# 6         NOAA          9569
# 7        PHMSA          8522
# 8          NRC          6630
# 9        NHTSA          5376
# 10         CMS          4858
# 11         DOD          4835
# 12         FRA          4499
# 13       MARAD          4446
# 14         DOS          4260

# %% [markdown]
# ## Query Documents

# %%
# Documents with open comment periods
# Note: dates are stored as strings, so we cast to DATE for comparison
conn.execute(f"""
    SELECT document_id, agency_code, title, comment_start_date, comment_end_date
    FROM read_parquet('{R2_BASE_URL}/documents.parquet')
    WHERE comment_end_date IS NOT NULL
      AND TRY_CAST(comment_end_date AS DATE) > CURRENT_DATE
    ORDER BY comment_end_date ASC
    LIMIT 10
""").fetchdf()
# Out:
#              document_id agency_code  \
# 0     DEA-2025-0918-0002         DEA
# 1    DEA_FRDOC_0001-0498         DEA
# 2  DOD-2025-OS-0476-0002         DOD
# 3  DOD-2025-OS-0475-0002         DOD
# 4  DOD-2025-OS-0540-0003         DOD
# 5    DOL_FRDOC_0001-2598         DOL
# 6    DOL_FRDOC_0001-2597         DOL
# 7   EPA_FRDOC_0001-32440         EPA
# 8   EPA_FRDOC_0001-32464         EPA
# 9   EPA_FRDOC_0001-32439         EPA
#
#                                                title    comment_start_date  \
# 0  Schedules of Controlled Substances: Placement ...  2025-12-16T05:00:00Z
# 1  Schedules of Controlled Substances: Placement ...  2025-12-16T05:00:00Z
# 2  Agency Information Collection Activities; Prop...  2025-12-16T05:00:00Z
# 3  Agency Information Collection Activities; Prop...  2025-12-16T05:00:00Z
# 4  Agency Information Collection Activities; Prop...  2025-12-16T05:00:00Z
# 5  Agency Information Collection Activities; Prop...  2025-12-16T05:00:00Z
# 6  Agency Information Collection Activities; Prop...  2025-12-16T05:00:00Z
# 7  Pesticide Petitions: Residues of Pesticide Che...  2025-12-16T05:00:00Z
# 8  Charter Amendments, Establishments, Renewals a...  2026-01-02T05:00:00Z
# 9  Pesticide Product Registration: Applications f...  2025-12-16T05:00:00Z
#
#        comment_end_date
# 0  2026-01-16T04:59:59Z
# 1  2026-01-16T04:59:59Z
# 2  2026-01-16T04:59:59Z
# 3  2026-01-16T04:59:59Z
# 4  2026-01-16T04:59:59Z
# 5  2026-01-16T04:59:59Z
# 6  2026-01-16T04:59:59Z
# 7  2026-01-16T04:59:59Z
# 8  2026-01-16T04:59:59Z
# 9  2026-01-16T04:59:59Z

# %% [markdown]
# ## Query Comments

# %%
# Recent comments
conn.execute(f"""
    SELECT comment_id, docket_id, agency_code, title, posted_date
    FROM read_parquet('{R2_BASE_URL}/comments.parquet')
    ORDER BY posted_date DESC
    LIMIT 10
""").fetchdf()
# Out:
#               comment_id         docket_id agency_code  \
# 0  AMS-FGIS-25-0155-0006  AMS-FGIS-25-0155         AMS
# 1  AMS-FGIS-25-0155-0005  AMS-FGIS-25-0155         AMS
# 2    BOEM-2025-0351-1091    BOEM-2025-0351        BOEM
# 3    BOEM-2025-0351-1090    BOEM-2025-0351        BOEM
# 4    BOEM-2025-0351-1089    BOEM-2025-0351        BOEM
# 5    BOEM-2025-0351-1085    BOEM-2025-0351        BOEM
# 6    BOEM-2025-0351-1094    BOEM-2025-0351        BOEM
# 7    BOEM-2025-0351-1096    BOEM-2025-0351        BOEM
# 8    BOEM-2025-0351-1095    BOEM-2025-0351        BOEM
# 9    BOEM-2025-0351-1118    BOEM-2025-0351        BOEM
#
#                                title           posted_date
# 0             Comment from Anonymous  2026-01-14T05:00:00Z
# 1  Comment from Riceland Foods, Inc.  2026-01-14T05:00:00Z
# 2     Comment from Miyawaki, Rintaro  2026-01-14T05:00:00Z
# 3          Comment from Drabe, Simon  2026-01-14T05:00:00Z
# 4             Comment from Anonymous  2026-01-14T05:00:00Z
# 5                  Comment from C, K  2026-01-14T05:00:00Z
# 6             Comment from Anonymous  2026-01-14T05:00:00Z
# 7         Comment from Obyrne, Nancy  2026-01-14T05:00:00Z
# 8           Comment from Lee, Minnie  2026-01-14T05:00:00Z
# 9    Comment from Knoeppel, Kathleen  2026-01-14T05:00:00Z

# %%
# Comments on a specific docket
docket_id = "EPA-HQ-OW-2025-0322"  # Change this to any docket ID

conn.execute(f"""
    SELECT comment_id, title, posted_date
    FROM read_parquet('{R2_BASE_URL}/comments.parquet')
    WHERE docket_id = '{docket_id}'
    ORDER BY posted_date DESC
    LIMIT 20
""").fetchdf()
# Out:
#                   comment_id                                    title  \
# 0   EPA-HQ-OW-2025-0322-1213        Comment submitted by Dianna Cohen
# 1   EPA-HQ-OW-2025-0322-1204     Comment submitted by Lauren Redfield
# 2   EPA-HQ-OW-2025-0322-1202                 Anonymous public comment
# 3   EPA-HQ-OW-2025-0322-1229          Comment submitted by Rob Erbele
# 4   EPA-HQ-OW-2025-0322-1215       Comment submitted by Michael Shore
# 5   EPA-HQ-OW-2025-0322-1219        Comment submitted by Homer Hansen
# 6   EPA-HQ-OW-2025-0322-1228      Comment submitted by Stanley Weston
# 7   EPA-HQ-OW-2025-0322-1227   Comment submitted by Nicholas Pandolfi
# 8   EPA-HQ-OW-2025-0322-1232         Comment submitted by Scott Glass
# 9   EPA-HQ-OW-2025-0322-1233                 Anonymous public comment
# 10  EPA-HQ-OW-2025-0322-1218   Comment submitted by Christopher Wentz
# 11  EPA-HQ-OW-2025-0322-1214      Comment submitted by Gregg DeBoever
# 12  EPA-HQ-OW-2025-0322-1221        Comment submitted by Samuel Uribe
# 13  EPA-HQ-OW-2025-0322-1209         Comment submitted by Linda Denny
# 14  EPA-HQ-OW-2025-0322-1231    Comment submitted by Tabitha McCauley
# 15  EPA-HQ-OW-2025-0322-1234                 Anonymous public comment
# 16  EPA-HQ-OW-2025-0322-1206      Comment submitted by David Van Waus
# 17  EPA-HQ-OW-2025-0322-1230  Comment submitted by Minerva Macarrulla
# 18  EPA-HQ-OW-2025-0322-1248             Comment submitted by Ha Ande
# 19  EPA-HQ-OW-2025-0322-1238          Comment submitted by Zan Heglin
#
#              posted_date
# 0   2026-01-14T05:00:00Z
# 1   2026-01-14T05:00:00Z
# 2   2026-01-14T05:00:00Z
# 3   2026-01-14T05:00:00Z
# 4   2026-01-14T05:00:00Z
# 5   2026-01-14T05:00:00Z
# 6   2026-01-14T05:00:00Z
# 7   2026-01-14T05:00:00Z
# 8   2026-01-14T05:00:00Z
# 9   2026-01-14T05:00:00Z
# 10  2026-01-14T05:00:00Z
# 11  2026-01-14T05:00:00Z
# 12  2026-01-14T05:00:00Z
# 13  2026-01-14T05:00:00Z
# 14  2026-01-14T05:00:00Z
# 15  2026-01-14T05:00:00Z
# 16  2026-01-14T05:00:00Z
# 17  2026-01-14T05:00:00Z
# 18  2026-01-14T05:00:00Z
# 19  2026-01-14T05:00:00Z

# %% [markdown]
# ## Advanced: Join Across Tables

# %%
# Dockets with comment counts
conn.execute(f"""
    SELECT 
        d.docket_id,
        d.agency_code,
        d.title,
        COUNT(c.comment_id) as comment_count
    FROM read_parquet('{R2_BASE_URL}/dockets.parquet') d
    LEFT JOIN read_parquet('{R2_BASE_URL}/comments.parquet') c
        ON d.docket_id = c.docket_id
    WHERE d.agency_code = 'EPA'
    GROUP BY d.docket_id, d.agency_code, d.title
    ORDER BY comment_count DESC
    LIMIT 10
""").fetchdf()
# Out:
#               docket_id agency_code  \
# 0  EPA-HQ-OAR-2023-0072         EPA
# 1  EPA-HQ-OAR-2022-0829         EPA
# 2  EPA-HQ-OAR-2015-0072         EPA
# 3  EPA-HQ-OAR-2018-0794         EPA
# 4  EPA-HQ-OAR-2022-0985         EPA
# 5   EPA-HQ-OW-2022-0801         EPA
# 6   EPA-HQ-OW-2009-0819         EPA
# 7  EPA-HQ-OAR-2022-0730         EPA
# 8   EPA-HQ-OW-2022-0114         EPA
# 9  EPA-HQ-OAR-2021-0317         EPA
#
#                                                title  comment_count
# 0  New Source Performance Standards for GHG Emiss...         690660
# 1  Multi-Pollutant Emissions Standards for Model ...         366420
# 2  Review of the National Ambient Air Quality Sta...         242821
# 3  National Emission Standards for Hazardous Air ...         242220
# 4  Greenhouse Gas Emissions Standards for Heavy-D...         155700
# 5  National Primary Drinking Water Regulations: L...         129360
# 6  Rulemaking for the Steam Electric Power Genera...         123156
# 7  New Source Performance Standards for the Synth...         117880
# 8  Per- and polyfluoroalkyl substances (PFAS): Pe...          95030
# 9  Standards of Performance for New, Reconstructe...          80058
