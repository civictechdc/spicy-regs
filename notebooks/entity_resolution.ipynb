# %% [markdown]
# # Entity Resolution
#
# **Problem**: How can we identify and unify organization names across dockets, accounting for aliases and inconsistent naming conventions?
#
# **Stakeholder Quotes:**
# - "Make it easier to determine which organizations submitted comments."
# - "We need entity disambiguation."
#
# This notebook demonstrates:
# - Extracting organization names from comment titles
# - Identifying variations of the same entity
# - Building a canonical entity mapping
# - Tracking organizations across dockets

# %%
import duckdb
import pandas as pd
from collections import Counter
import re

R2_BASE_URL = "https://pub-5fc11ad134984edf8d9af452dd1849d6.r2.dev"

conn = duckdb.connect()
conn.execute("INSTALL httpfs; LOAD httpfs;")
print("✓ Ready")
# Out:
# ✓ Ready

# %% [markdown]
# ## 1. Extract Commenter Names
#
# Comment titles often contain the submitter's name/organization.

# %%
# Sample comment titles to understand naming patterns
titles = conn.execute(f"""
    SELECT title, docket_id, posted_date
    FROM read_parquet('{R2_BASE_URL}/comments.parquet')
    WHERE title IS NOT NULL
      AND LENGTH(title) > 10
    LIMIT 100
""").fetchdf()

print("Sample comment titles:")
for t in titles['title'].head(20):
    print(f"  - {t[:80]}")
# Out:
# Sample comment titles:
#   - SACWIS Public Comments
#   - Comment on FR Doc # E7-24860
#   - Comment on FR Doc # E7-24860
#   - Comment on FR Doc # E7-24860
#   - AFCARS PUBLIC COMMENTS
#   - Comment on FR Doc # 2010-23583
#   - Comment on AFCARS NPRM
#   - Comment on FR Doc # 2010-23583
#   - SACWIS Public Comments
#   - AFCARS NPRM
#   - Comment on FR Doc # 2010-23583
#   - AFCARS PUBLIC COMMENT
#   - Comment on FR Doc # 2010-23583
#   - Comment on FR Doc # E8-28812
#   - Comment on AFCARS NPRM
#   - Comment on FR Doc # 2010-23583
#   - SACWIS Public Comments
#   - Comment on AFCARS NPRM
#   - Comments Regarding Regulations For Tribal Title IV-E
#   - Comment on FR Doc # 2010-23583

# %% [markdown]
# ## 2. Find Frequent Commenters
#
# Organizations that comment frequently across dockets.

# %%
# Most frequent comment titles (often org names)
frequent = conn.execute(f"""
    SELECT 
        title,
        COUNT(*) as comment_count,
        COUNT(DISTINCT docket_id) as docket_count
    FROM read_parquet('{R2_BASE_URL}/comments.parquet')
    WHERE title IS NOT NULL
      AND title NOT LIKE 'Comment%'
      AND title NOT LIKE 'Anonymous%'
      AND LENGTH(title) > 5
    GROUP BY title
    HAVING COUNT(DISTINCT docket_id) > 5
    ORDER BY docket_count DESC
    LIMIT 30
""").fetchdf()

print("Frequent commenters across multiple dockets:")
frequent
# Out:
# Frequent commenters across multiple dockets:
#                                                 title  comment_count  \
# 0     Submitted Electronically via eRulemaking Portal         684529
# 1                          Boeing Commercial Airplane            424
# 2    Advocates for Highway and Auto Safety - Comments            869
# 3                                  The Boeing Company            385
# 4                                     United Airlines            279
# 5                                      Public Comment          11544
# 6                         Boeing Commercial Airplanes            259
# 7          Air Line Pilots Association, International            258
# 8                  Air Line Pilots Association, Int'l            244
# 9                                   American Airlines            259
# 10          American Trucking Associations - Comments            276
# 11                           Aviation Partners Boeing            187
# 12           Unrelated Comment Submitted by Anonymous            496
# 13                                             Airbus            196
# 14                                    Delta Air Lines            176
# 15             Aircraft Owners and Pilots Association            193
# 16                                             Boeing            162
# 17                                      FedEx Express            163
# 18                        Air Line Pilots Association            152
# 19               National Transportation Safety Board            160
# 20                             Barb Sachau - Comments            153
# 21                                           Attached            359
# 22                          Air Transport Association            142
# 23       Association of American Railroads - Comments            166
# 24  Washington State Department of Transportation ...            132
# 25                                Small UAV Coalition            121
# 26      Commercial Vehicle Safety Alliance - Comments            137
# 27  Wisconsin Department of Transportation - Comments            117
# 28                           U.S. DOT/RSPA - Comments            169
# 29  American Public Transportation Association - C...            128
#
#     docket_count
# 0            694
# 1            387
# 2            364
# 3            352
# 4            261
# 5            258
# 6            245
# 7            243
# 8            236
# 9            229
# 10           207
# 11           179
# 12           174
# 13           171
# 14           169
# 15           167
# 16           158
# 17           154
# 18           145
# 19           141
# 20           139
# 21           135
# 22           132
# 23           132
# 24           119
# 25           115
# 26           108
# 27           107
# 28           107
# 29           105

# %% [markdown]
# ## 3. Identify Organization Patterns
#
# Look for common organizational suffixes and patterns.

# %%
# Find titles containing org indicators
org_patterns = ['Association', 'Institute', 'Foundation', 'Corporation', 'Inc.', 
                'LLC', 'Council', 'Coalition', 'Alliance', 'Federation', 'Union',
                'Chamber', 'Society', 'Board', 'Commission', 'Agency']

pattern_clause = " OR ".join([f"title LIKE '%{p}%'" for p in org_patterns])

orgs = conn.execute(f"""
    SELECT 
        title,
        COUNT(*) as comments,
        COUNT(DISTINCT docket_id) as dockets,
        COUNT(DISTINCT agency_code) as agencies
    FROM read_parquet('{R2_BASE_URL}/comments.parquet')
    WHERE ({pattern_clause})
    GROUP BY title
    HAVING COUNT(*) > 3
    ORDER BY dockets DESC
    LIMIT 50
""").fetchdf()

print(f"Found {len(orgs)} organizations with multiple comments:")
orgs
# Out:
# Found 50 organizations with multiple comments:
#                                                 title  comments  dockets  \
# 0     Comment from Air Line Pilots Association, Int'l       551      528
# 1   Comment from Advanced Medical Technology Assoc...       323      256
# 2          Air Line Pilots Association, International       258      243
# 3                  Air Line Pilots Association, Int'l       244      236
# 4           American Trucking Associations - Comments       276      207
# 5   Comment submitted by American Chemistry Counci...       413      178
# 6              Aircraft Owners and Pilots Association       193      167
# 7                         Air Line Pilots Association       152      145
# 8               Comment from U.S. Chamber of Commerce       161      141
# 9                National Transportation Safety Board       160      141
# 10       Association of American Railroads - Comments       166      132
# 11                          Air Transport Association       142      132
# 12                                Small UAV Coalition       121      115
# 13          Comment from Citizens Rulemaking Alliance       117      115
# 14  Comment from Air Line Pilots Association, Inte...       113      112
# 15      Commercial Vehicle Safety Alliance - Comments       137      108
# 16  Comment from Association for Accessible Medici...       112      107
# 17  American Public Transportation Association - C...       128      105
# 18                   Comment from Small UAV Coalition       113      105
# 19  Comment submitted by Andrew D. Moore, Executiv...       123       99
# 20        Comment from American Trucking Associations       103       98
# 21  Comment from Consumer Healthcare Products Asso...       108       98
# 22                      Comment from Cook Group, Inc.       109       96
# 23  Comment submitted by American Petroleum Instit...       162       95
# 24    Alliance of Automobile Manufacturers - Comments       122       94
# 25         National Agricultural Aviation Association        96       93
# 26  Comment submitted by National Agricultural Avi...       117       90
# 27                       American Bankers Association        96       88
# 28    Comment from Alliance for Automotive Innovation       109       87
# 29                 Comment from Delta Air Lines, Inc.        87       84
# 30  Insurance Institute for Highway Safety - Comments       113       83
# 31    National Transportation Safety Board - Comments        96       83
# 32            Comment from American Chemistry Council        95       82
# 33  Modification and Replacement Parts Association...        84       81
# 34                              Delta Air Lines, Inc.        93       81
# 35       Comment from American Farm Bureau Federation        97       80
# 36  Advanced Medical Technology Association (AdvaM...        89       78
# 37             Comment from ACT | The App Association        92       77
# 38  Comment from Air Line Pilots Association Inter...        82       77
# 39  Comment from American Public Transportation As...        85       77
# 40     Comment from Natural Resources Defense Council       104       75
# 41  Comment from American Pharmacists Association ...        83       75
# 42                      Comment from Chambers, Claire       199       72
# 43  National Automobile Dealers Association - Comm...        86       71
# 44                American Bus Association - Comments        95       70
# 45     Comment from Air Line Pilots Association Int'l        69       68
# 46  American Association of State Highway and Tran...        86       68
# 47                          Comment from Pfizer, Inc.        72       67
# 48  Comment from American Association of State Hig...        76       67
# 49    American Trucking Associations, Inc. - Comments        76       67
#
#     agencies
# 0          4
# 1          6
# 2          4
# 3          2
# 4          8
# 5          1
# 6          3
# 7          3
# 8         31
# 9          5
# 10         5
# 11         3
# 12         1
# 13        13
# 14         5
# 15         4
# 16         2
# 17         6
# 18         5
# 19         1
# 20        14
# 21         1
# 22         1
# 23         1
# 24         4
# 25         1
# 26         1
# 27         3
# 28        12
# 29         2
# 30         4
# 31         9
# 32        15
# 33         1
# 34         3
# 35        14
# 36         1
# 37        15
# 38         3
# 39        11
# 40        18
# 41         2
# 42        16
# 43         5
# 44         5
# 45         1
# 46         6
# 47         1
# 48        10
# 49         6

# %% [markdown]
# ## 4. Fuzzy Name Matching
#
# Find variations of the same entity name.

# %%
# Simple approach: find titles that share the first N characters
# This catches "American Petroleum Institute" vs "American Petroleum Institute (API)"

prefix_matches = conn.execute(f"""
    SELECT 
        LEFT(title, 30) as name_prefix,
        COUNT(DISTINCT title) as variations,
        COUNT(*) as total_comments,
        ARRAY_AGG(DISTINCT title) as all_variations
    FROM read_parquet('{R2_BASE_URL}/comments.parquet')
    WHERE title IS NOT NULL
      AND LENGTH(title) > 30
    GROUP BY LEFT(title, 30)
    HAVING COUNT(DISTINCT title) > 1
    ORDER BY variations DESC
    LIMIT 20
""").fetchdf()

print("Entity name variations (potential duplicates to merge):")
for _, row in prefix_matches.iterrows():
    print(f"\n{row['name_prefix']}... ({row['variations']} variations, {row['total_comments']} comments)")
    for v in row['all_variations'][:5]:
        print(f"  - {v[:60]}")
# Out:
# Entity name variations (potential duplicates to merge):
#
# BIS Decision Memo - BIS-2018-0... (81186 variations, 88647 comments)
#   - BIS Decision Memo - BIS-2018-0006-166085
#   - BIS Decision Memo - BIS-2018-0006-119814
#   - BIS Decision Memo - BIS-2018-0006-87820
#   - BIS Decision Memo - BIS-2018-0006-117474
#   - BIS Decision Memo - BIS-2018-0006-114758
#
# Planned Parenthood Mass Mailin... (36488 variations, 37638 comments)
#   - Planned Parenthood Mass Mailing, Donna, Prinzmetal - OR
#   - Planned Parenthood Mass Mailing, Michael, Smar - IL
#   - Planned Parenthood Mass Mailing, Emily, Schneider - OH
#   - Planned Parenthood Mass Mailing, Philip, Steier - NE
#   - Planned Parenthood Mass Mailing, Cynthia, Wick - MD
#
# [TF] Template Form Comment - (... (9789 variations, 43333 comments)
#   - [TF] Template Form Comment - (no last name), superNEScube -
#   - [TF] Template Form Comment - (no last name), Peter - First R
#   - [TF] Template Form Comment - (no last name), Gareth - First
#   - [TF] Template Form Comment - (no last name), Christopher - F
#   - [TF] Template Form Comment - (no last name), Marcel - First
#
# EBSA-2023-0010, EBSA-2023-0010... (8752 variations, 9502 comments)
#   - EBSA-2023-0010, EBSA-2023-0010-0001, 2023-15945, Patricia, H
#   - EBSA-2023-0010, EBSA-2023-0010-0001, 2023-15945, American Ac
#   - EBSA-2023-0010, EBSA-2023-0010-0001, 2023-15945, Business Gr
#   - EBSA-2023-0010, EBSA-2023-0010-0001, 2023-15945, Silver Psyc
#   - EBSA-2023-0010, EBSA-2023-0010-0001, 2023-15945, Lane, Krump
#
# MM49 Comment Submitted by Chri... (4491 variations, 5454 comments)
#   - MM49 Comment Submitted by Chris Spathelf
#   - MM49 Comment Submitted by Christian De leon
#   - MM49 Comment Submitted by Christina Whitehead
#   - MM49 Comment Submitted by Christopher wheeler
#   - MM49 Comment Submitted by Christopher McClaic
#
# MM49 Comment Submitted by Mich... (4318 variations, 5960 comments)
#   - MM49 Comment Submitted by Michael Worzella
#   - MM49 Comment Submitted by Michael Wood
#   - MM49 Comment Submitted by Michael St. Onge
#   - MM49 Comment Submitted by Michael Clifford
#   - MM49 Comment Submitted by Michelle Hays
#
# Comment Submitted by Jennifer ... (4081 variations, 6481 comments)
#   - Comment Submitted by Jennifer Foss
#   - Comment Submitted by Jennifer Tucker
#   - Comment Submitted by Jennifer Abubakari
#   - Comment Submitted by Jennifer Bibbo, St. Thomas More Catholi
#   - Comment Submitted by Jennifer Hanley
#
# Comment Submitted by Elizabeth... (3763 variations, 7085 comments)
#   - Comment Submitted by Elizabeth Garvey
#   - Comment Submitted by Elizabeth Wiederhold, Seller Solutions
#   - Comment Submitted by Elizabeth W. Horton
#   - Comment Submitted by Elizabeth Fan
#   - Comment Submitted by Elizabeth Ankrom
#
# Comment Submitted by Patricia ... (3358 variations, 7074 comments)
#   - Comment Submitted by Patricia Glenn
#   - Comment Submitted by Patricia Barton
#   - Comment Submitted by Patricia Falk
#   - Comment Submitted by Patricia Donley
#   - Comment Submitted by Patricia Haste
#
# MM49 Comment Submitted by John... (3262 variations, 4308 comments)
#   - MM49 Comment Submitted by John Carroll
#   - MM49 Comment Submitted by John DeAmaral
#   - MM49 Comment Submitted by Johnnie Day
#   - MM49 Comment Submitted by Johnny Hamm
#   - MM49 Comment Submitted by Johnjeffrey Green
#
# MM49 Comment Submitted by Mari... (3229 variations, 3971 comments)
#   - MM49 Comment Submitted by Marieta Wagner
#   - MM49 Comment Submitted by Marie Larsen
#   - MM49 Comment Submitted by Maribel Quintana
#   - MM49 Comment Submitted by Mario Hanson
#   - MM49 Comment Submitted by Maria Rincon
#
# [TF] Template Form Comment - S... (3133 variations, 3399 comments)
#   - [TF] Template Form Comment - Sanchez, Isaac - First Round Co
#   - [TF] Template Form Comment - Shaver, Nicholas - First Round
#   - [TF] Template Form Comment - Shaw, James - First Round Comme
#   - [TF] Template Form Comment - Stockley, Adam - First Round Co
#   - [TF] Template Form Comment - Sisson, Kelly - First Round Com
#
# [TF] Template Form Comment - M... (3049 variations, 3217 comments)
#   - [TF] Template Form Comment - Miller, Agatha - First Round Co
#   - [TF] Template Form Comment - Mitchell, Colin - First Round C
#   - [TF] Template Form Comment - McTee, Dakota - First Round Com
#   - [TF] Template Form Comment - Marte, Girey - First Round Comm
#   - [TF] Template Form Comment - McQuade, Cameron - First Round
#
# [TF] Template Form Comment - B... (2679 variations, 2804 comments)
#   - [TF] Template Form Comment - Bezdziecki, Russell - First Rou
#   - [TF] Template Form Comment - Briggs, Paul - First Round Comm
#   - [TF] Template Form Comment - Bridwell, Michael - First Round
#   - [TF] Template Form Comment - Bergquist, Mark - First Round C
#   - [TF] Template Form Comment - Bentez, Rodrigo - First Round C
#
# MM49 Comment Submitted by Jame... (2672 variations, 3897 comments)
#   - MM49 Comment Submitted by James Morin
#   - MM49 Comment Submitted by James Sampson
#   - MM49 Comment Submitted by James Timblin
#   - MM49 Comment Submitted by James Walker
#   - MM49 Comment Submitted by James Venable
#
# Comment Submitted by Michelle ... (2623 variations, 4095 comments)
#   - Comment Submitted by Michelle McGinness, McGinness Mortgage
#   - Comment Submitted by Michelle Manier
#   - Comment Submitted by Michelle Camp, Michelle Camp
#   - Comment Submitted by Michelle Rigney
#   - Comment Submitted by Michelle Caldern
#
# Comment Submitted by Christoph... (2557 variations, 3900 comments)
#   - Comment Submitted by Christopher  Nanni, Community Foundatio
#   - Comment Submitted by Christopher Leonard
#   - Comment Submitted by Christopher Diethert
#   - Comment Submitted by Christopher Auretta, NA
#   - Comment Submitted by Christopher gabriel Castro sanchez
#
# BIS Decision Memos - BIS-2018-... (2536 variations, 2543 comments)
#   - BIS Decision Memos - BIS-2018-0006-119025
#   - BIS Decision Memos - BIS-2018-0006-121726
#   - BIS Decision Memos - BIS-2018-0006-93725
#   - BIS Decision Memos - BIS-2018-0006-120663
#   - BIS Decision Memos - BIS-2018-0006-119908
#
# MM49 Comment Submitted by Jose... (2536 variations, 3774 comments)
#   - MM49 Comment Submitted by Joseph Scott
#   - MM49 Comment Submitted by Joseph King
#   - MM49 Comment Submitted by Jose Reinoso
#   - MM49 Comment Submitted by Joseph Morales
#   - MM49 Comment Submitted by Joseph Warrick
#
# MM49 Comment Submitted by Davi... (2529 variations, 3507 comments)
#   - MM49 Comment Submitted by David Mottys
#   - MM49 Comment Submitted by David LeGrande
#   - MM49 Comment Submitted by Davian Dorman
#   - MM49 Comment Submitted by David Hoover
#   - MM49 Comment Submitted by David Kinlock

# %% [markdown]
# ## 5. Track Entity Across Dockets

# %%
# Track a specific organization's commenting activity
org_name = "Sierra Club"  # Change this to track different orgs

org_activity = conn.execute(f"""
    SELECT 
        c.docket_id,
        d.title as docket_title,
        d.agency_code,
        c.posted_date,
        c.title as comment_title
    FROM read_parquet('{R2_BASE_URL}/comments.parquet') c
    LEFT JOIN read_parquet('{R2_BASE_URL}/dockets.parquet') d
        ON c.docket_id = d.docket_id
    WHERE LOWER(c.title) LIKE '%{org_name.lower()}%'
    ORDER BY c.posted_date DESC
    LIMIT 25
""").fetchdf()

print(f"{org_name} commenting activity:")
org_activity
# Out:
# Sierra Club commenting activity:
#                 docket_id                                       docket_title  \
# 0   EPA-R09-OAR-2025-1938  Air Plan Approval; California; San Joaquin Val...
# 1     EPA-HQ-OW-2025-0322  Updated Definition of Waters of the United States
# 2     EPA-HQ-OW-2025-0322  Updated Definition of Waters of the United States
# 3     EPA-HQ-OW-2025-0322  Updated Definition of Waters of the United States
# 4     EPA-HQ-OW-2025-0322  Updated Definition of Waters of the United States
# 5     EPA-HQ-OW-2025-0322  Updated Definition of Waters of the United States
# 6     EPA-HQ-OW-2025-0322  Updated Definition of Waters of the United States
# 7     EPA-HQ-OW-2002-0072       Process for Designing a Watershed Initiative
# 8     EPA-HQ-OW-2002-0072       Process for Designing a Watershed Initiative
# 9   EPA-HQ-OPPT-2020-0549  Reporting and Recordkeeping for Perfluoroalkyl...
# 10  EPA-HQ-OPPT-2020-0549  Reporting and Recordkeeping for Perfluoroalkyl...
# 11  EPA-HQ-OPPT-2020-0549  Reporting and Recordkeeping for Perfluoroalkyl...
# 12    EPA-HQ-OW-2025-0322  Updated Definition of Waters of the United States
# 13        NHTSA-2025-0491  The Safer Affordable Fuel-Efficient (SAFE) Veh...
# 14        NHTSA-2025-0490  Supplemental EIS for the Safer Affordable Fuel...
# 15    FWS-HQ-ES-2025-0048  Endangered and Threatened Wildlife and Plants;...
# 16    FWS-HQ-ES-2025-0029  Endangered and Threatened Wildlife and Plants;...
# 17    FWS-HQ-ES-2025-0044  Endangered and Threatened Wildlife and Plants;...
# 18    FWS-HQ-ES-2025-0039  Endangered and Threatened Wildlife and Plants;...
# 19    FWS-R6-ES-2024-0186  Endangered and Threatened Wildlife and Plants;...
# 20        NHTSA-2025-0491  The Safer Affordable Fuel-Efficient (SAFE) Veh...
# 21  EPA-R09-OAR-2025-2466  Approval of Clean Air Plans; San Joaquin Valle...
# 22    FWS-HQ-ES-2025-0039  Endangered and Threatened Wildlife and Plants;...
# 23   EPA-HQ-OAR-2025-1477  Visibility Protection: Regional Haze State Pla...
# 24   EPA-HQ-OAR-2025-1477  Visibility Protection: Regional Haze State Pla...
#
#    agency_code           posted_date  \
# 0          EPA  2026-01-14T05:00:00Z
# 1          EPA  2026-01-14T05:00:00Z
# 2          EPA  2026-01-12T05:00:00Z
# 3          EPA  2026-01-12T05:00:00Z
# 4          EPA  2026-01-06T05:00:00Z
# 5          EPA  2026-01-06T05:00:00Z
# 6          EPA  2026-01-06T05:00:00Z
# 7          EPA  2026-01-02T05:00:00Z
# 8          EPA  2026-01-02T05:00:00Z
# 9          EPA  2025-12-31T05:00:00Z
# 10         EPA  2025-12-31T05:00:00Z
# 11         EPA  2025-12-31T05:00:00Z
# 12         EPA  2025-12-30T05:00:00Z
# 13       NHTSA  2025-12-23T05:00:00Z
# 14       NHTSA  2025-12-23T05:00:00Z
# 15         FWS  2025-12-22T05:00:00Z
# 16         FWS  2025-12-22T05:00:00Z
# 17         FWS  2025-12-22T05:00:00Z
# 18         FWS  2025-12-22T05:00:00Z
# 19         FWS  2025-12-22T05:00:00Z
# 20       NHTSA  2025-12-19T05:00:00Z
# 21         EPA  2025-12-17T05:00:00Z
# 22         FWS  2025-12-15T05:00:00Z
# 23         EPA  2025-12-02T05:00:00Z
# 24         EPA  2025-12-02T05:00:00Z
#
#                                         comment_title
# 0   Comment submitted by Committee for a Better Ar...
# 1   Comment submitted by Lehigh Valley Group of th...
# 2   Comment submitted by Sierra Club et al. (Part ...
# 3   Comment submitted by Sierra Club et al. (Part ...
# 4   Comment submitted by Illinois Chapter of the S...
# 5   Comment submitted by Piasa Palisades Group, Si...
# 6      Mass Comment Campaign sponsored by Sierra Club
# 7   Comment submitted by Cumberland (Kentucky) Cha...
# 8   Comment submitted by Cumberland (Kentucky) Cha...
# 9                    Comment submitted by Sierra Club
# 10                   Comment submitted by Sierra Club
# 11                   Comment submitted by Sierra Club
# 12  Comment submitted by Sierra Club Florida Chapt...
# 13  Comment from Center for Biological Diversity, ...
# 14  Comment from Center for Biological Diversity, ...
# 15                      Mass Mailing from Sierra Club
# 16                      Mass Mailing from Sierra Club
# 17                      Mass Mailing from Sierra Club
# 18                      Mass Mailing from Sierra Club
# 19  Comment from Earthjustice on behalf of Center ...
# 20                           Comment from Sierra Club
# 21  Comment submitted by CCEJN, Committee for a Be...
# 22             Comment from Member of the Sierra club
# 23  Comment submitted by Sierra Club et al. (Part ...
# 24  Comment submitted by Sierra Club et al. (Part ...

# %% [markdown]
# ## 6. Build Entity Classification
#
# Classify entities by type (industry, advocacy, government, individual).

# %%
# Simple keyword-based classification
classifications = {
    'industry': ['Corporation', 'Inc.', 'LLC', 'Corp.', 'Company', 'Industries'],
    'trade_association': ['Association', 'Federation', 'Chamber', 'Council'],
    'advocacy': ['Sierra Club', 'EDF', 'NRDC', 'Citizens', 'Action', 'Watch'],
    'academic': ['University', 'College', 'Institute', 'Professor', 'PhD'],
    'government': ['Department', 'Agency', 'Commission', 'State of', 'City of']
}

# Build classification query
case_clauses = []
for entity_type, keywords in classifications.items():
    conditions = " OR ".join([f"title LIKE '%{kw}%'" for kw in keywords])
    case_clauses.append(f"WHEN {conditions} THEN '{entity_type}'")

case_stmt = "CASE " + " ".join(case_clauses) + " ELSE 'individual' END"

entity_breakdown = conn.execute(f"""
    SELECT 
        {case_stmt} as entity_type,
        COUNT(*) as comment_count,
        COUNT(DISTINCT docket_id) as dockets
    FROM read_parquet('{R2_BASE_URL}/comments.parquet')
    WHERE title IS NOT NULL
    GROUP BY entity_type
    ORDER BY comment_count DESC
""").fetchdf()

print("Comment breakdown by entity type:")
entity_breakdown
# Out:
# Comment breakdown by entity type:
#          entity_type  comment_count  dockets
# 0         individual       24379915    53985
# 1           industry         172278    14152
# 2  trade_association         123473    15875
# 3         government          56682     8042
# 4           academic          29246     6860
# 5           advocacy          13079     3390
